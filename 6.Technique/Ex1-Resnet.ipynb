# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Flatten, MaxPooling2D, Dense, Conv2D, AveragePooling2D, BatchNormalization, Dropout, Activation, Input, Add
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.utils import to_categorical

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step

# %%
x_train = (x_train / 255).astype('float32')
x_test = (x_test / 255).astype('float32')

# %%
numClasses = np.unique(y_train).shape[0]

fig, axe = plt.subplots(numClasses, numClasses, figsize=(10, 10))

for i in range (numClasses):
  for j in range (numClasses):
    k = np.random.choice(range(len(x_train)))
    axe[i][j].imshow(x_train[k])
    axe[i][j].set_axis_off()

# %%
def lr_shedule(epoch):
  """
  epoch: number of epochs

  return learning rate
  """
  lr = 0.001
  if epoch > 20:
    return 0.0001
  elif epoch > 15:
    return 0.0005
  elif epoch > 10:
    return 0.0008
  return lr

# %%
def residual_block(inputs, downsample, number_filters):
  y = Conv2D(number_filters,
             (3,3),
             strides=(1 if not downsample else 2),
             padding='same',
             kernel_regularizer=l2(0.001))(inputs)
  y = Activation('relu')(y)
  y = BatchNormalization()(y)

  y = Conv2D(number_filters,
             (3,3),
             strides=1,
             padding='same',
             kernel_regularizer=l2(0.001))(y)

  if downsample:
    inputs = Conv2D(number_filters,
                    (1,1),
                    strides=2,
                    padding='same',
                    kernel_regularizer=l2(0.001))(inputs)
    
  outputs = Add()([inputs, y])
  outputs = BatchNormalization()(outputs)
  outputs = Activation('relu')(outputs)

  return outputs

# %%
def res_net():

  inputs = Input((32,32,3))
  num_filters = 32

  y = Conv2D(num_filters,
                (3,3),
                strides=1,
                padding='same')(inputs)
  y = BatchNormalization()(y)
  y = Activation('relu')(y)

  ''''
  model = Sequential()
  model.add(Conv2D(.., input_shape=(32, 32, 3)))
  model.add(BatchNorm...)
  model.add(Activation)
  '''

  num_blocks_list = [2, 3, 3, 2]

  for i in range(len(num_blocks_list)):
    num_blocks = num_blocks_list[i]
    for j in range (num_blocks):
      y = residual_block(y, downsample=(j==0 and i!=0), number_filters=num_filters)
    num_filters *= 2

  y = AveragePooling2D(4)(y)
  y = Flatten()(y)
  y = Dense(512, activation='relu')(y)
  y = Dropout(0.4)(y)
  outputs = Dense(10, activation='softmax')(y)

  model = Model(inputs, outputs)

  model.compile(loss='categorical_crossentropy',
                optimizer='adam',
                metrics=['accuracy'])
  
  return model

# %%
model = res_net()
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 32)   128         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 32)   9248        activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 32)   128         activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 32)   9248        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 32)   0           activation[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 32)   128         add[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 32)   9248        activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 32)   128         activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   9248        batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 32)   0           activation_2[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 32)   128         add_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 64)   18496       activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 64)   256         activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 64)   2112        activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 64)   36928       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 64)   0           conv2d_7[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 64)   256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 64)   36928       activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 64)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 64)   256         activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 64)   36928       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 64)   0           activation_6[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 64)   256         add_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 64)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 64)   256         activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 64)   36928       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 64)   0           activation_8[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 64)   256         add_4[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 128)    73856       activation_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 128)    0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 128)    512         activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 128)    8320        activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 128)    147584      batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 128)    0           conv2d_14[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 128)    512         add_5[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 128)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 128)    147584      activation_12[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 128)    0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 128)    512         activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 128)    147584      batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 128)    0           activation_12[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 128)    512         add_6[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 128)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 128)    147584      activation_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 128)    0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 128)    512         activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 128)    147584      batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 128)    0           activation_14[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 128)    512         add_7[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 128)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 256)    295168      activation_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 4, 4, 256)    0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 4, 4, 256)    1024        activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 4, 4, 256)    33024       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 256)    590080      batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 4, 4, 256)    0           conv2d_21[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 4, 4, 256)    1024        add_8[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 4, 4, 256)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 4, 4, 256)    590080      activation_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 4, 4, 256)    0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 4, 4, 256)    1024        activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 4, 4, 256)    590080      batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 4, 4, 256)    0           activation_18[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 4, 4, 256)    1024        add_9[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 4, 4, 256)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 256)    0           activation_20[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 256)          0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          131584      flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           5130        dropout[0][0]
# ==================================================================================================
# Total params: 3,307,722
# Trainable params: 3,303,050
# Non-trainable params: 4,672
# __________________________________________________________________________________________________

# %%
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
hist = model.fit(x_train, y_train,
                 epochs=25,
                 batch_size=256,
                 callbacks=[LearningRateScheduler(lr_shedule)],
                 validation_data=(x_test,y_test),
                 verbose=1)
# Out:
# Epoch 1/25
#   2/196 [..............................] - ETA: 8s - loss: 4.8324 - accuracy: 0.1230WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0337s vs `on_train_batch_end` time: 0.0521s). Check your callbacks.
# 196/196 [==============================] - 19s 98ms/step - loss: 3.2415 - accuracy: 0.4331 - val_loss: 4.5124 - val_accuracy: 0.1000
# Epoch 2/25
# 196/196 [==============================] - 19s 95ms/step - loss: 1.9738 - accuracy: 0.6131 - val_loss: 2.6533 - val_accuracy: 0.3848
# Epoch 3/25
# 196/196 [==============================] - 19s 96ms/step - loss: 1.5175 - accuracy: 0.7010 - val_loss: 2.4156 - val_accuracy: 0.4319
# Epoch 4/25
# 196/196 [==============================] - 19s 98ms/step - loss: 1.3036 - accuracy: 0.7490 - val_loss: 1.4511 - val_accuracy: 0.6979
# Epoch 5/25
# 196/196 [==============================] - 19s 99ms/step - loss: 1.1623 - accuracy: 0.7788 - val_loss: 1.3660 - val_accuracy: 0.6928
# Epoch 6/25
# 196/196 [==============================] - 19s 99ms/step - loss: 1.0619 - accuracy: 0.8036 - val_loss: 1.3082 - val_accuracy: 0.7088
# Epoch 7/25
# 196/196 [==============================] - 19s 99ms/step - loss: 0.9956 - accuracy: 0.8225 - val_loss: 1.2525 - val_accuracy: 0.7325
# Epoch 8/25
# 196/196 [==============================] - 20s 101ms/step - loss: 0.9334 - accuracy: 0.8347 - val_loss: 1.2416 - val_accuracy: 0.7407
# Epoch 9/25
# 196/196 [==============================] - 20s 101ms/step - loss: 0.9000 - accuracy: 0.8445 - val_loss: 1.1770 - val_accuracy: 0.7629
# Epoch 10/25
# 196/196 [==============================] - 20s 100ms/step - loss: 0.8590 - accuracy: 0.8583 - val_loss: 1.1967 - val_accuracy: 0.7608
# Epoch 11/25
# 196/196 [==============================] - 20s 100ms/step - loss: 0.8462 - accuracy: 0.8623 - val_loss: 1.2808 - val_accuracy: 0.7422
# Epoch 12/25
# 196/196 [==============================] - 20s 100ms/step - loss: 0.7484 - accuracy: 0.8897 - val_loss: 1.2258 - val_accuracy: 0.7407
# Epoch 13/25
# 196/196 [==============================] - 20s 101ms/step - loss: 0.7122 - accuracy: 0.8977 - val_loss: 1.2453 - val_accuracy: 0.7504
# Epoch 14/25
# 196/196 [==============================] - 20s 101ms/step - loss: 0.6961 - accuracy: 0.9046 - val_loss: 1.1018 - val_accuracy: 0.7849
# Epoch 15/25
# 196/196 [==============================] - 20s 101ms/step - loss: 0.6743 - accuracy: 0.9113 - val_loss: 1.2227 - val_accuracy: 0.7485
# Epoch 16/25
# 196/196 [==============================] - 20s 101ms/step - loss: 0.6647 - accuracy: 0.9151 - val_loss: 1.2568 - val_accuracy: 0.7515
# Epoch 17/25
# 196/196 [==============================] - 20s 100ms/step - loss: 0.5433 - accuracy: 0.9510 - val_loss: 0.9571 - val_accuracy: 0.8279
# Epoch 18/25
# 196/196 [==============================] - 20s 101ms/step - loss: 0.4954 - accuracy: 0.9581 - val_loss: 1.0520 - val_accuracy: 0.8087
# Epoch 19/25
# 196/196 [==============================] - 20s 100ms/step - loss: 0.4823 - accuracy: 0.9602 - val_loss: 1.0881 - val_accuracy: 0.8088
# Epoch 20/25
# 196/196 [==============================] - 20s 100ms/step - loss: 0.4781 - accuracy: 0.9595 - val_loss: 1.1021 - val_accuracy: 0.8106
# Epoch 21/25
# 196/196 [==============================] - 20s 100ms/step - loss: 0.4739 - accuracy: 0.9590 - val_loss: 1.0298 - val_accuracy: 0.8238
# Epoch 22/25
# 196/196 [==============================] - 20s 101ms/step - loss: 0.3908 - accuracy: 0.9880 - val_loss: 0.8635 - val_accuracy: 0.8649
# Epoch 23/25
# 196/196 [==============================] - 20s 101ms/step - loss: 0.3454 - accuracy: 0.9986 - val_loss: 0.9008 - val_accuracy: 0.8657
# Epoch 24/25
# 196/196 [==============================] - 20s 101ms/step - loss: 0.3261 - accuracy: 0.9997 - val_loss: 0.9298 - val_accuracy: 0.8637
# Epoch 25/25
# 196/196 [==============================] - 20s 101ms/step - loss: 0.3106 - accuracy: 0.9996 - val_loss: 0.9518 - val_accuracy: 0.8638

# %%
hist.history['accuracy']
# Out:
# [0.43314000964164734,
#  0.6131399869918823,
#  0.700980007648468,
#  0.7490000128746033,
#  0.7787600159645081,
#  0.8035600185394287,
#  0.8224999904632568,
#  0.8347200155258179,
#  0.844539999961853,
#  0.8582599759101868,
#  0.8623200058937073,
#  0.8896600008010864,
#  0.8977400064468384,
#  0.9046400189399719,
#  0.9113199710845947,
#  0.9151399731636047,
#  0.9509599804878235,
#  0.958079993724823,
#  0.9602199792861938,
#  0.9595000147819519,
#  0.9589599967002869,
#  0.9879599809646606,
#  0.9986400008201599,
#  0.9997199773788452,
#  0.9995999932289124]
