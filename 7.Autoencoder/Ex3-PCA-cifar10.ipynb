# %%
import numpy as np
import pandas as pd
import keras
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D,Dropout
from keras.models import Model
from sklearn.model_selection import train_test_split
from keras.datasets import cifar10
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.decomposition import PCA

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
label_dict = {
 0: 'airplane',
 1: 'automobile',
 2: 'bird',
 3: 'cat',
 4: 'deer',
 5: 'dog',
 6: 'frog',
 7: 'horse',
 8: 'ship',
 9: 'truck',
}

# %%
plt.figure(figsize=[5,5])

# Display the first image in training data
plt.subplot(121)
curr_img = np.reshape(x_train[0], (32,32,3))
plt.imshow(curr_img)
print(plt.title("(Label: " + str(label_dict[y_train[0][0]]) + ")"))

# Display the first image in testing data
plt.subplot(122)
curr_img = np.reshape(x_test[0],(32,32,3))
plt.imshow(curr_img)
print(plt.title("(Label: " + str(label_dict[y_test[0][0]]) + ")"))
# Out:
# Text(0.5, 1.0, '(Label: frog)')
# Text(0.5, 1.0, '(Label: cat)')

# %%
classes = np.unique(y_train)

# %%
np.min(x_train),np.max(x_train)
# Out:
# (0, 255)

# %%
x_train = x_train/255.0
x_train_flat = x_train.reshape(-1,3072)
feat_cols = ['pixel'+str(i) for i in range(x_train_flat.shape[1])]
df_cifar = pd.DataFrame(x_train_flat,columns=feat_cols)
df_cifar['label'] = y_train

# %%
df_cifar.head()
# Out:
#      pixel0    pixel1    pixel2  ...  pixel3070  pixel3071  label
# 0  0.231373  0.243137  0.247059  ...   0.360784   0.282353      6
# 1  0.603922  0.694118  0.733333  ...   0.521569   0.564706      9
# 2  1.000000  1.000000  1.000000  ...   0.337255   0.329412      9
# 3  0.109804  0.098039  0.039216  ...   0.254902   0.180392      4
# 4  0.666667  0.705882  0.776471  ...   0.301961   0.313725      1
#
# [5 rows x 3073 columns]

# %%
pca_cifar = PCA(n_components=2)
principalComponents_cifar = pca_cifar.fit_transform(df_cifar.iloc[:,:-1])

# %%
principal_cifar_Df = pd.DataFrame(data = principalComponents_cifar
             , columns = ['principal component 1', 'principal component 2'])
principal_cifar_Df['y'] = y_train

# %%
principal_cifar_Df.head()
# Out:
#    principal component 1  principal component 2  y
# 0              -6.401018               2.729039  6
# 1               0.829783              -0.949943  9
# 2               7.730200             -11.522103  9
# 3             -10.347817               0.010738  4
# 4              -2.625651              -4.969240  1

# %%
print('Explained variation per principal component: {}'.format(pca_cifar.explained_variance_ratio_))
# Out:
# Explained variation per principal component: [0.2907663  0.11253144]

# %%
import seaborn as sns
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="principal component 1", y="principal component 2",
    hue="y",
    palette=sns.color_palette("hls", 10),
    data=principal_cifar_Df,
    legend="full",
    alpha=0.3
)

# %%
x_test = x_test/255.0
x_test = x_test.reshape(-1,32,32,3)
x_test_flat = x_test.reshape(-1,3072)
pca = PCA(0.9)
pca.fit(x_train_flat)
pca.n_components_
# Out:
# 99

# %%
train_img_pca = pca.transform(x_train_flat)
test_img_pca = pca.transform(x_test_flat)
test_img_pca.shape
# Out:
# (10000, 99)

# %%
y_test.shape
# Out:
# (10000, 1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
from keras.optimizers import RMSprop

# %%
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# %%
batch_size = 128
num_classes = 10
epochs = 20

# %%
model = Sequential()
model.add(Dense(1024, activation='relu', input_shape=(99,)))
model.add(Dense(1024, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              102400
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 1,810,698
# Trainable params: 1,810,698
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history1 = model.fit(train_img_pca, y_train,batch_size=batch_size,epochs=epochs,verbose=1,
                    validation_data=(test_img_pca, y_test))
# Out:
# Epoch 1/20
# 391/391 [==============================] - 19s 50ms/step - loss: 1.6325 - accuracy: 0.4209 - val_loss: 1.4354 - val_accuracy: 0.4969
# Epoch 2/20
# 391/391 [==============================] - 19s 49ms/step - loss: 1.3155 - accuracy: 0.5354 - val_loss: 1.3359 - val_accuracy: 0.5275
# Epoch 3/20
# 391/391 [==============================] - 19s 50ms/step - loss: 1.1390 - accuracy: 0.5923 - val_loss: 1.3794 - val_accuracy: 0.5210
# Epoch 4/20
# 391/391 [==============================] - 20s 51ms/step - loss: 0.9807 - accuracy: 0.6486 - val_loss: 1.3567 - val_accuracy: 0.5479
# Epoch 5/20
# 391/391 [==============================] - 19s 49ms/step - loss: 0.8329 - accuracy: 0.7030 - val_loss: 1.3625 - val_accuracy: 0.5637
# Epoch 6/20
# 391/391 [==============================] - 19s 49ms/step - loss: 0.6900 - accuracy: 0.7519 - val_loss: 1.5972 - val_accuracy: 0.5438
# Epoch 7/20
# 391/391 [==============================] - 19s 49ms/step - loss: 0.5637 - accuracy: 0.7998 - val_loss: 1.6608 - val_accuracy: 0.5431
# Epoch 8/20
# 391/391 [==============================] - 19s 49ms/step - loss: 0.4623 - accuracy: 0.8366 - val_loss: 1.7886 - val_accuracy: 0.5435
# Epoch 9/20
# 391/391 [==============================] - 19s 49ms/step - loss: 0.3913 - accuracy: 0.8628 - val_loss: 2.2090 - val_accuracy: 0.5407
# Epoch 10/20
# 391/391 [==============================] - 19s 49ms/step - loss: 0.3316 - accuracy: 0.8864 - val_loss: 2.5151 - val_accuracy: 0.5425
# Epoch 11/20
# 391/391 [==============================] - 19s 49ms/step - loss: 0.2889 - accuracy: 0.9038 - val_loss: 2.5310 - val_accuracy: 0.5440
# Epoch 12/20
# 391/391 [==============================] - 19s 49ms/step - loss: 0.2636 - accuracy: 0.9129 - val_loss: 2.4543 - val_accuracy: 0.5366
# Epoch 13/20
# 391/391 [==============================] - 19s 49ms/step - loss: 0.2401 - accuracy: 0.9213 - val_loss: 3.2900 - val_accuracy: 0.5450
# Epoch 14/20
# 391/391 [==============================] - 19s 48ms/step - loss: 0.2265 - accuracy: 0.9270 - val_loss: 3.1624 - val_accuracy: 0.5382
# Epoch 15/20
# 391/391 [==============================] - 19s 49ms/step - loss: 0.2122 - accuracy: 0.9322 - val_loss: 3.4884 - val_accuracy: 0.5406
# Epoch 16/20
# 391/391 [==============================] - 20s 50ms/step - loss: 0.1980 - accuracy: 0.9370 - val_loss: 3.5168 - val_accuracy: 0.5464
# Epoch 17/20
# 391/391 [==============================] - 19s 48ms/step - loss: 0.1942 - accuracy: 0.9405 - val_loss: 2.9426 - val_accuracy: 0.5432
# Epoch 18/20
# 391/391 [==============================] - 19s 48ms/step - loss: 0.1878 - accuracy: 0.9430 - val_loss: 3.2478 - val_accuracy: 0.5413
# Epoch 19/20
# 391/391 [==============================] - 19s 48ms/step - loss: 0.1809 - accuracy: 0.9457 - val_loss: 4.1144 - val_accuracy: 0.5335
# Epoch 20/20
# 391/391 [==============================] - 19s 49ms/step - loss: 0.1768 - accuracy: 0.9470 - val_loss: 3.8484 - val_accuracy: 0.5418

# %%
model = Sequential()
model.add(Dense(1024, activation='relu', input_shape=(3072,)))
model.add(Dense(1024, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history2 = model.fit(x_train_flat, y_train,batch_size=batch_size,epochs=epochs,verbose=1,
                    validation_data=(x_test_flat, y_test))
# Out:
# Epoch 1/20
# 391/391 [==============================] - 39s 99ms/step - loss: 2.1727 - accuracy: 0.2443 - val_loss: 1.8194 - val_accuracy: 0.3408
# Epoch 2/20
# 391/391 [==============================] - 39s 101ms/step - loss: 1.8237 - accuracy: 0.3393 - val_loss: 1.7056 - val_accuracy: 0.3930
# Epoch 3/20
# 391/391 [==============================] - 39s 101ms/step - loss: 1.7242 - accuracy: 0.3834 - val_loss: 1.6780 - val_accuracy: 0.3876
# Epoch 4/20
# 391/391 [==============================] - 39s 100ms/step - loss: 1.6516 - accuracy: 0.4076 - val_loss: 1.6371 - val_accuracy: 0.4081
# Epoch 5/20
# 391/391 [==============================] - 39s 99ms/step - loss: 1.6056 - accuracy: 0.4282 - val_loss: 1.7490 - val_accuracy: 0.3947
# Epoch 6/20
# 391/391 [==============================] - 39s 99ms/step - loss: 1.5617 - accuracy: 0.4413 - val_loss: 1.5433 - val_accuracy: 0.4525
# Epoch 7/20
# 391/391 [==============================] - 39s 99ms/step - loss: 1.5237 - accuracy: 0.4562 - val_loss: 1.6325 - val_accuracy: 0.4348
# Epoch 8/20
#  21/391 [>.............................] - ETA: 32s - loss: 1.5044 - accuracy: 0.4706
