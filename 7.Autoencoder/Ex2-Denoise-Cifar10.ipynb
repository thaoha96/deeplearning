# %%
import numpy as np
import keras
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D,Dropout
from keras.models import Model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from keras.datasets import cifar10
# %matplotlib inline

# %%
(cifar_train, _), (cifar_test, _) = cifar10.load_data()

size = 32
channel = 3
# scaling input data
cifar_train = cifar_train / 255
cifar_test = cifar_test / 255

# Adding noise mean = 0, std = 0.3
noise = 0.3
cifar_train_noise = cifar_train + noise * np.random.normal(0, 0.3, size=cifar_train.shape) 
cifar_test_noise = cifar_test + noise * np.random.normal(0, 0.3, size=cifar_test.shape)

cifar_train_noise = np.clip(cifar_train_noise, 0, 1)
cifar_test_noise = np.clip(cifar_test_noise, 0, 1)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step

# %%
# Visualize few training images with their noisy images

rows = 2 
cols = 8 

f = plt.figure(figsize=(2*cols,2*rows*2)) 

for i in range(rows):
    for j in range(cols): 
        f.add_subplot(rows*2,cols, (2*i*cols)+(j+1)) 
        plt.imshow(cifar_train_noise[i*cols + j]) 
        plt.axis("off")
        
    for j in range(cols): 
        f.add_subplot(rows*2,cols,((2*i+1)*cols)+(j+1)) 
        plt.imshow(cifar_train[i*cols + j]) 
        plt.axis("off")
        
f.suptitle("Sample Training Data",fontsize=18)
plt.savefig("Cifar-trian.png")

plt.show()

# %%
from keras.layers import Conv2DTranspose, BatchNormalization, add, LeakyReLU
from keras.optimizers import Adam

# %%
# Encoder 
inputs = Input(shape=(size,size,channel))

x = Conv2D(32, 3, activation='relu', padding='same')(inputs)
x = BatchNormalization()(x)
x = MaxPooling2D()(x)
x = Dropout(0.5)(x)
skip = Conv2D(32, 3, padding='same')(x) # skip connection for decoder
x = LeakyReLU()(skip)
x = BatchNormalization()(x)
x = MaxPooling2D()(x)
x = Dropout(0.5)(x)
x = Conv2D(64, 3, activation='relu', padding='same')(x)
x = BatchNormalization()(x)
encoded = MaxPooling2D()(x)

# Decoder
x = Conv2DTranspose(64, 3,activation='relu',strides=(2,2), padding='same')(encoded)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Conv2DTranspose(32, 3, activation='relu',strides=(2,2), padding='same')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Conv2DTranspose(32, 3, padding='same')(x)
x = add([x,skip]) # adding skip connection
x = LeakyReLU()(x)
x = BatchNormalization()(x)
decoded = Conv2DTranspose(3, 3, activation='sigmoid',strides=(2,2), padding='same')(x)

autoencoder = Model(inputs, decoded)
autoencoder.compile(optimizer=Adam(lr=0.001), loss='binary_crossentropy')
autoencoder.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   896         input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 32)   128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 32)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 32)   9248        dropout_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 16, 16, 32)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 32)   128         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 32)     0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 8, 8, 32)     0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 64)     18496       dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8, 8, 64)     256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 4, 4, 64)     0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 8, 8, 64)     36928       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 8, 64)     256         conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 64)     0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 32)   18464       dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 32)   128         conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 32)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 16, 16, 32)   9248        dropout_5[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 16, 16, 32)   0           conv2d_transpose_2[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 16, 16, 32)   0           add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 32)   128         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 32, 32, 3)    867         batch_normalization_10[0][0]
# ==================================================================================================
# Total params: 95,171
# Trainable params: 94,659
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
# Training
epochs = 25
batch_size = 256

history = autoencoder.fit(cifar_train_noise,
                cifar_train,
                epochs=epochs,
                batch_size=batch_size,
                shuffle=True,
                validation_data=(cifar_test_noise, cifar_test)
               )
# Out:
# Epoch 1/25
# 196/196 [==============================] - 163s 832ms/step - loss: 0.5787 - val_loss: 0.6113
# Epoch 2/25
# 196/196 [==============================] - 165s 842ms/step - loss: 0.5617 - val_loss: 0.5757
# Epoch 3/25
# 196/196 [==============================] - 165s 839ms/step - loss: 0.5599 - val_loss: 0.5624
# Epoch 4/25
# 196/196 [==============================] - 165s 843ms/step - loss: 0.5591 - val_loss: 0.5600
# Epoch 5/25
# 196/196 [==============================] - 165s 840ms/step - loss: 0.5585 - val_loss: 0.5576
# Epoch 6/25
# 196/196 [==============================] - 165s 842ms/step - loss: 0.5581 - val_loss: 0.5567
# Epoch 7/25
# 196/196 [==============================] - 166s 848ms/step - loss: 0.5578 - val_loss: 0.5556
# Epoch 8/25
# 196/196 [==============================] - 166s 849ms/step - loss: 0.5576 - val_loss: 0.5561
# Epoch 9/25
# 196/196 [==============================] - 166s 845ms/step - loss: 0.5574 - val_loss: 0.5549
# Epoch 10/25
# 196/196 [==============================] - 166s 846ms/step - loss: 0.5573 - val_loss: 0.5550
# Epoch 11/25
# 196/196 [==============================] - 165s 842ms/step - loss: 0.5572 - val_loss: 0.5552
# Epoch 12/25
# 196/196 [==============================] - 165s 841ms/step - loss: 0.5570 - val_loss: 0.5553
# Epoch 13/25
# 196/196 [==============================] - 165s 842ms/step - loss: 0.5569 - val_loss: 0.5546
# Epoch 14/25
# 196/196 [==============================] - 166s 846ms/step - loss: 0.5569 - val_loss: 0.5546
# Epoch 15/25
# 196/196 [==============================] - 165s 842ms/step - loss: 0.5568 - val_loss: 0.5548
# Epoch 16/25
# 196/196 [==============================] - 165s 840ms/step - loss: 0.5567 - val_loss: 0.5547
# Epoch 17/25
# 196/196 [==============================] - 164s 836ms/step - loss: 0.5567 - val_loss: 0.5543
# Epoch 18/25
# 196/196 [==============================] - 165s 839ms/step - loss: 0.5566 - val_loss: 0.5549
# Epoch 19/25
# 196/196 [==============================] - 164s 838ms/step - loss: 0.5566 - val_loss: 0.5546
# Epoch 20/25
# 196/196 [==============================] - 165s 840ms/step - loss: 0.5565 - val_loss: 0.5545
# Epoch 21/25
# 196/196 [==============================] - 164s 839ms/step - loss: 0.5565 - val_loss: 0.5541
# Epoch 22/25
# 196/196 [==============================] - 165s 843ms/step - loss: 0.5565 - val_loss: 0.5547
# Epoch 23/25
# 196/196 [==============================] - 164s 838ms/step - loss: 0.5564 - val_loss: 0.5546
# Epoch 24/25
# 196/196 [==============================] - 165s 841ms/step - loss: 0.5564 - val_loss: 0.5542
# Epoch 25/25
# 196/196 [==============================] - 164s 835ms/step - loss: 0.5564 - val_loss: 0.5542

# %%
# Defining Figure
f = plt.figure(figsize=(10,7))
f.add_subplot()

#Adding Subplot
plt.plot(history.epoch, history.history['loss'], label = "loss") # Loss curve for training set
plt.plot(history.epoch, history.history['val_loss'], label = "val_loss") # Loss curve for validation set

plt.title("Loss Curve",fontsize=18)
plt.xlabel("Epochs",fontsize=15)
plt.ylabel("Loss",fontsize=15)
plt.grid(alpha=0.3)
plt.legend()
plt.savefig("Loss_curve_cifar10.png")
plt.show()

# %%
# Select few random test images
num_imgs = 48
rand = np.random.randint(1, cifar_test_noise.shape[0]-48) 

cifar_test_images = cifar_test_noise[rand:rand+num_imgs] # slicing
cifar_test_desoided = autoencoder.predict(cifar_test_images) # predict

# %%
# Visualize test images with their denoised images

rows = 4 # defining no. of rows in figure
cols = 12 # defining no. of colums in figure
cell_size = 1.5
f = plt.figure(figsize=(cell_size*cols,cell_size*rows*2)) # defining a figure 
f.tight_layout()
for i in range(rows):
    for j in range(cols): 
        f.add_subplot(rows*2,cols, (2*i*cols)+(j+1)) # adding sub plot to figure on each iteration
        plt.imshow(cifar_test_images[i*cols + j]) 
        plt.axis("off")
        
    for j in range(cols): 
        f.add_subplot(rows*2,cols,((2*i+1)*cols)+(j+1)) # adding sub plot to figure on each iteration
        plt.imshow(cifar_test_desoided[i*cols + j]) 
        plt.axis("off")

f.suptitle("Autoencoder Results - Cifar10",fontsize=18)
plt.savefig("test_results_cifar10.png")

plt.show()
